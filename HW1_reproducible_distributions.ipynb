# %% [markdown]
# # I want you to create a <i>reproducible research</i> code
# that means we want the reader to be able to reproduce every step of our analysis. when stochastic processes and random variables are involved that gets tricky, but since computers are unable to rpoduce truly random numbers, we can actually reproduce every series of "pseudo random" number generated by a computer as long as we know what seed is used. <i>The first seed will determin entirely the distribution that is generated, and the seeds of the following distriburions generated by the code!</i>

# %%
import os
import sys
import numpy as np

# %% [markdown]
# #THIS IS THE MOST IMPORTANT PIECE OF THIS CODE!
# ##we must give numpy as seed for this code to be reproducible
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.seed.html

# %%
np.random.seed(1729)

# %% [markdown]
# ##use this function to generate 100 2-dimensional random datapoints in a gaussian distribution in 2 dimensions
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.random.randn.html

# %%
np.random.seed(1729) 
data=np.random.randn(100,2)
data
mu=round(data.mean(),2)
stdev=round(data.std(),2)

# %% [markdown]
# ## use the same function to generate 50 more random objects, but this time change the mean
# to do that you multiply the distribution by a different sigma, and add your new mean - remember that these are 2D objects, so yor mean must be a 2D vector (a list, an array or a tuple)!

# %%
np.random.seed(1729) 
data2 = np.random.randn(50,2)+15
mu2=round(data2.mean(),2)
stdev2=round(data2.std(),2)
data2
# Out:
# array([[ 14.31266056,  14.17900529],
#        [ 16.65236086,  14.42470696],
#        [ 16.09896774,  15.92594603],
#        [ 14.00658621,  14.14177886],
#        [ 15.07488676,  15.52935554],
#        [ 15.12095155,  14.77557639],
#        [ 13.44332151,  15.05594088],
#        [ 15.16147154,  12.86535824],
#        [ 15.10967005,  15.44301216],
#        [ 15.39626623,  15.24979741],
#        [ 16.29849737,  13.71956633],
#        [ 14.02453416,  14.73091336],
#        [ 13.89426164,  14.87200729],
#        [ 14.38217262,  14.01087376],
#        [ 12.14010769,  14.20565248],
#        [ 14.69420305,  16.70063762],
#        [ 14.36455581,  15.00457387],
#        [ 16.13330404,  15.14164127],
#        [ 17.091718  ,  13.73044078],
#        [ 14.27717664,  14.98061111],
#        [ 14.81717642,  13.88093422],
#        [ 14.30172489,  17.10708457],
#        [ 14.9974444 ,  15.40901006],
#        [ 15.28363676,  13.05014551],
#        [ 15.38603087,  15.23064111],
#        [ 13.81302922,  14.33344842],
#        [ 16.79776687,  15.66379836],
#        [ 16.1238116 ,  13.86569384],
#        [ 16.18444973,  15.70126236],
#        [ 15.45549638,  14.9185131 ],
#        [ 13.90413146,  15.44071689],
#        [ 16.64270848,  15.44795941],
#        [ 14.21328329,  14.82685701],
#        [ 17.31948219,  14.67139544],
#        [ 14.76114303,  14.78328484],
#        [ 15.98742695,  16.80691957],
#        [ 14.43568625,  15.5435365 ],
#        [ 15.54287858,  15.20713796],
#        [ 14.76872642,  15.28251922],
#        [ 13.95312607,  14.16265442],
#        [ 15.01644864,  13.84551419],
#        [ 16.40001124,  14.75218855],
#        [ 12.33943039,  15.01723553],
#        [ 14.8834819 ,  16.12143921],
#        [ 14.64788334,  13.94728123],
#        [ 13.09405495,  14.65312168],
#        [ 15.29723299,  13.00735534],
#        [ 16.190012  ,  13.99663131],
#        [ 16.30519262,  14.17561697],
#        [ 15.11207436,  14.55063496]])

# %% [markdown]
# ##now plot them with this function:
#
# https://scipy-lectures.github.io/intro/matplotlib/matplotlib.html#scatter-plots
#
# ##if you print the array it will be a 2x100: 100 2D objects. although that is what we wanted we cannot plot it easily this way: there are many ways to deal with it. the goal is to pass the first dimension as the disrt argument to scatter, and the second dimension as the second argument. i am gonna do it by transposing the array (switching the axes)

# %%
#unsure what disrt argument means?
import pylab as pl
# %pylab inline
X = data.T[0]
Y = data.T[1]

pl.scatter(X,Y, color = 'blue', alpha=0.8)
pl.xlabel("X")
pl.ylabel("Y")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##first plot them as a single distribution, then change the color for the 2 samples
#
# remember to give your labels some names and to make a legend! in the legend tell me what the mean and standard deviation of each sample is

# %%
#unsure what disrt argument means?
import pylab as pl
# %pylab inline
X = data.T[0]
Y = data.T[1]
X2 = data2.T[0]
Y2 = data2.T[1]
pl.scatter(X,Y, color = 'blue', alpha=0.5, label='mean: '+str(mu)+' Standard Dev: '+str(stdev))
pl.scatter(X2,Y2, color = 'green',alpha = 0.5,label='mean: '+str(mu2)+' Standard Dev: '+str(stdev2))
pl.legend(loc='center')
pl.xlabel("X")
pl.ylabel("Y")
# Out:
# Populating the interactive namespace from numpy and matplotlib
